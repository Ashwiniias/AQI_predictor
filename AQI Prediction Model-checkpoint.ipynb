# %% [markdown]
# ### AQI Prediction Model Using Python

# %% [markdown]
# - PM2.5 PM10
# - NO, N02
# - NH3-Ammonia
# - CO
# - So2
# - O3
# - Benzene,Toulene,Xylene

# %%
pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('air quality index.csv')
df.head() #top5
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
# shape -rows and columns
df.shape
# Out:
# (29531, 16)

# %%
#information
df.info
# Out:
# <bound method DataFrame.info of                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
# to know duplicate values
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29526    False
# 29527    False
# 29528    False
# 29529    False
# 29530    False
# Length: 29531, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df.dropna(subset=['AQI'],inplace=True)

# %%
df.isnull().sum().sort_values(ascending=True)
# Out:
# City              0
# Date              0
# AQI_Bucket        0
# AQI               0
# NO              387
# NO2             391
# CO              445
# SO2             605
# PM2.5           678
# O3              807
# NOx            1857
# Benzene        3535
# Toluene        5826
# NH3            6536
# PM10           7086
# Xylene        15372
# dtype: int64

# %%
df.shape
# Out:
# (24850, 16)

# %%
df.describe().T
# Out:
#            count        mean         std    min     25%     50%       75%  \
# PM2.5    24933.0   67.450578   64.661449   0.04  28.820   48.57   80.5900
# PM10     18391.0  118.127103   90.605110   0.01  56.255   95.68  149.7450
# NO       25949.0   17.574730   22.785846   0.02   5.630    9.89   19.9500
# NO2      25946.0   28.560659   24.474746   0.01  11.750   21.69   37.6200
# NOx      25346.0   32.309123   31.646011   0.00  12.820   23.52   40.1275
# NH3      19203.0   23.483476   25.684275   0.01   8.580   15.85   30.0200
# CO       27472.0    2.248598    6.962884   0.00   0.510    0.89    1.4500
# SO2      25677.0   14.531977   18.133775   0.01   5.670    9.16   15.2200
# O3       25509.0   34.491430   21.694928   0.01  18.860   30.84   45.5700
# Benzene  23908.0    3.280840   15.811136   0.00   0.120    1.07    3.0800
# Toluene  21490.0    8.700972   19.969164   0.00   0.600    2.97    9.1500
# Xylene   11422.0    3.070128    6.323247   0.00   0.140    0.98    3.3500
# ...

# %% [markdown]
# ### Week 2-visualization

# %%
#univariate analysis
df['Xylene'].plot(kind = 'hist', figsize=(9,6))
plt.legend()
plt.show()

# %%
df['PM10'].plot(kind = 'hist', figsize=(9,6))
plt.legend()
plt.show()

# %%
df['NH3'].plot(kind = 'hist', figsize=(9,6))
plt.legend()
plt.show()

# %%
df['Toluene'].plot(kind = 'hist', figsize=(9,6))
plt.legend()
plt.show()

# %%
df['Benzene'].plot(kind = 'hist', figsize=(9,6))
plt.legend()
plt.show()

# %%
df['NOx'].plot(kind = 'hist', figsize=(9,6))
plt.legend()
plt.show()

# %%
df['AQI'].plot(kind = 'hist', figsize=(9,6))
plt.legend()
plt.show()

# %%
df['O3'].plot(kind = 'hist', figsize=(9,6))
plt.legend()
plt.show()

# %%
df['CO'].plot(kind = 'hist', figsize=(9,6))
plt.legend()
plt.show()

# %%
#distribution of AQI feom 2015 to 2020
sns.displot(df, x='AQI', color='red')

# %%
#BIVARIATE
sns.set_theme(style="darkgrid")
graph = sns.catplot(x= "City", kind='count', data=df, height=5, aspect=3)
graph.set_xticklabels(rotation=45)

# %%
sns.set_theme(style="darkgrid")
graph = sns.catplot(x= "City", kind='count', data=df, col="AQI_Bucket", col_wrap=2, height=3.5, aspect=3)
graph.set_xticklabels(rotation=45)

# %%
graph1 =sns.catplot(x='City', y='PM2.5',kind='box',data=df,height=5,aspect=3)
graph1.set_xticklabels(rotation=90)

# %%
graph2 =sns.catplot(x='City', y='NO2',kind='box',data=df,height=5,aspect=3)
graph2.set_xticklabels(rotation=90)

# %%
graph3 =sns.catplot(x='City', y='O3',kind='box',data=df,height=5,aspect=3)
graph3.set_xticklabels(rotation=90)

# %%
graph4 =sns.catplot(x='City', y='SO2',kind='box',data=df,height=5,aspect=3)
graph4.set_xticklabels(rotation=90)

# %%
graph5 =sns.catplot(x='AQI_Bucket',kind='count',data=df,height=6,aspect=3)
graph5.set_xticklabels(rotation=90)

# %%
# to check null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Xylene        18109
# PM10          11140
# NH3           10328
# Toluene        8041
# Benzene        5623
# AQI            4681
# AQI_Bucket     4681
# PM2.5          4598
# NOx            4185
# O3             4022
# SO2            3854
# NO2            3585
# NO             3582
# CO             2059
# Date              0
# City              0
# dtype: int64

# %%
df.describe().loc["mean"]
# Out:
# PM2.5       67.450578
# PM10       118.127103
# NO          17.574730
# NO2         28.560659
# NOx         32.309123
# NH3         23.483476
# CO           2.248598
# SO2         14.531977
# O3          34.491430
# Benzene      3.280840
# Toluene      8.700972
# Xylene       3.070128
# AQI        166.463581
# Name: mean, dtype: float64

# %%
df.replace({
    "PM2.5":{np.nan:67.450578},
    "PM10":{np.nan:118.127103},
    "NO":   {np.nan: 17.574730},
    "NO2":         {np.nan:28.560659},
"NOx":        {np.nan:32.309123},
"NH3":    {np.nan:23.483476},
"CO":{np.nan:2.248598},
"SO2 ":   {np.nan:   14.531977},
"O3":   {np.nan:    34.491430},
"Benzene": {np.nan:    3.280840},
"Toluene":{np.nan:   8.700972},
"Xylene ":{np.nan:   3.070128},

})
# Out:
#                 City        Date      PM2.5        PM10     NO    NO2    NOx  \
# 0          Ahmedabad  2015-01-01  67.450578  118.127103   0.92  18.22  17.15
# 1          Ahmedabad  2015-01-02  67.450578  118.127103   0.97  15.69  16.46
# 2          Ahmedabad  2015-01-03  67.450578  118.127103  17.40  19.30  29.70
# 3          Ahmedabad  2015-01-04  67.450578  118.127103   1.70  18.48  17.97
# 4          Ahmedabad  2015-01-05  67.450578  118.127103  22.10  21.42  37.76
# ...              ...         ...        ...         ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.020000   50.940000   7.68  25.06  19.54
# 29527  Visakhapatnam  2020-06-28  24.380000   74.090000   3.42  26.06  16.53
# 29528  Visakhapatnam  2020-06-29  22.910000   65.730000   3.45  29.53  18.33
# 29529  Visakhapatnam  2020-06-30  16.640000   49.970000   4.05  29.26  18.80
# 29530  Visakhapatnam  2020-07-01  15.000000   66.000000   0.40  26.85  14.05
#
# ...

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
sns.boxplot(data=df[['PM2.5', 'PM10']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['NO', 'NO2','NOx','NH3']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['O3', 'SO2']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['Benzene', 'Toluene']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['Xylene', 'AQI']])
# Out:
# <Axes: >

# %%
#IQR METHOD-Q3 Q1
def replace_outliers(df):
    for column in df.select_dtypes(include=['number']).columns:
            Q1=df[column].quantile(0.25)
            Q3=df[column].quantile(0.75)
            IQR=Q3-Q1
            lb=Q1-1.5*IQR
            ub=Q3+1.5*IQR
            df[column]=df[column].apply(
                lambda x:Q1 if x < lb else(Q3 if x > ub else x)
        )
    return df

# %%
df = replace_outliers(df)

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      54.975923    104.818086     12.472491     25.482607     26.520383
# std       32.781561     60.357602      8.941774     16.698364     17.876378
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.742500     19.950000     37.620000     40.125625
# max      158.210000    289.950000     41.430000     76.400000     81.060000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      19.661227      0.952485     10.304869     32.836577      1.676408
# ...

# %%
sns.boxplot(data=df[["PM2.5" ,"PM10"]])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[["O3" ,"SO2"]])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[["Benzene" ,"Toluene"]])
# Out:
# <Axes: >

# %%
sns.displot(df, x='AQI' , color='purple')
plt.show()

# %%
df1 = df.drop(columns=['City'])
